# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
import sas7bdat
from sas7bdat import *

# %%
from sklearn.model_selection import train_test_split
import statsmodels
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
from statsmodels.formula.api import ols

from scipy import stats
import scipy.stats as stats

# %%
# Reading dataset and creating dataframe
file=SAS7BDAT('walmart.sas7bdat')
file
# Out:
# SAS7BDAT file: walmart.sas7bdat

# %%
df=file.to_data_frame()
df.head()
# Out:
#    Customer_Satisfaction  Product_Quality  E_Commerce  Technical_Support  \
# 0                    8.2              8.5         3.9                2.5
# 1                    5.7              8.2         2.7                5.1
# 2                    8.9              9.2         3.4                5.6
# 3                    4.8              6.4         3.3                7.0
# 4                    7.1              9.0         3.4                5.2
#
#    Complaint_Resolution  Advertising  Product_Line  Salesforce_Image  \
# 0                   5.9          4.8           4.9               6.0
# 1                   7.2          3.4           7.9               3.1
# 2                   5.6          5.4           7.4               5.8
# 3                   3.7          4.7           4.7               4.5
# 4                   4.6          2.2           6.0               4.5
#
#    Competitive_Pricing  Warranty_Claims  Packaging  Order_Billing  \
# 0                  6.8              4.7        4.3            5.0
# 1                  5.3              5.5        4.0            3.9
# 2                  4.5              6.2        4.6            5.4
# 3                  8.8              7.0        3.6            4.3
# 4                  6.8              6.1        4.5            4.5
#
#    Price_Flexibility  Delivery_Speed
# 0                5.1             3.7
# 1                4.3             4.9
# 2                4.0             4.5
# 3                4.1             3.0
# 4                3.5             3.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 14 columns):
# Customer_Satisfaction    200 non-null float64
# Product_Quality          200 non-null float64
# E_Commerce               200 non-null float64
# Technical_Support        200 non-null float64
# Complaint_Resolution     200 non-null float64
# Advertising              200 non-null float64
# Product_Line             200 non-null float64
# Salesforce_Image         200 non-null float64
# Competitive_Pricing      200 non-null float64
# Warranty_Claims          200 non-null float64
# Packaging                200 non-null float64
# Order_Billing            200 non-null float64
# Price_Flexibility        200 non-null float64
# Delivery_Speed           200 non-null float64
# dtypes: float64(14)
# memory usage: 22.0 KB

# %%
# Check dimension of the dataset
df.shape
# Out:
# (200, 14)

# %%
# Check Column names
df.columns
# Out:
# Index(['Customer_Satisfaction', 'Product_Quality', 'E_Commerce',
#        'Technical_Support', 'Complaint_Resolution', 'Advertising',
#        'Product_Line', 'Salesforce_Image', 'Competitive_Pricing',
#        'Warranty_Claims', 'Packaging', 'Order_Billing', 'Price_Flexibility',
#        'Delivery_Speed'],
#       dtype='object')

# %%
# Check descriptive stats of each column
m=df.describe()
m
# Out:
#        Customer_Satisfaction  Product_Quality  E_Commerce  Technical_Support  \
# count             200.000000       200.000000  200.000000         200.000000
# mean                6.952000         7.894000    3.765000           5.243000
# std                 1.241128         1.383014    0.768916           1.655189
# min                 4.700000         5.000000    2.200000           0.400000
# 25%                 6.000000         6.700000    3.300000           4.100000
# 50%                 7.050000         8.050000    3.700000           5.300000
# 75%                 7.900000         9.100000    4.100000           6.425000
# max                 9.900000        10.000000    5.700000           8.900000
#
#        Complaint_Resolution  Advertising  Product_Line  Salesforce_Image  \
# count            200.000000    200.00000    200.000000        200.000000
# mean               5.367500      4.06150      5.815000          5.248000
# std                1.209964      1.14706      1.317404          1.128567
# min                1.500000      1.50000      2.300000          2.500000
# 25%                4.500000      3.20000      4.800000          4.575000
# 50%                5.400000      4.00000      5.700000          5.000000
# 75%                6.200000      4.92500      6.900000          6.000000
# max                8.700000      6.90000      8.400000          8.200000
#
#        Competitive_Pricing  Warranty_Claims   Packaging  Order_Billing  \
# count           200.000000       200.000000  200.000000     200.000000
# mean              6.971000         6.048500    5.210500       4.242000
# std               1.581253         0.875345    1.496005       0.911918
# min               3.700000         3.700000    1.200000       1.200000
# 25%               5.800000         5.400000    4.200000       3.700000
# 50%               7.150000         6.100000    5.200000       4.300000
# 75%               8.325000         6.600000    6.225000       4.700000
# max              10.000000         8.400000    9.500000       6.700000
#
#        Price_Flexibility  Delivery_Speed
# count         200.000000      200.000000
# mean            4.464000        3.816000
# std             1.192651        0.749368
# min             2.300000        1.600000
# 25%             3.575000        3.300000
# 50%             4.250000        3.900000
# 75%             5.325000        4.325000
# max             7.500000        5.500000

# %%
# 80% for training & 20% for testing
train,test=train_test_split(df,test_size=0.2,random_state=2)

# %%
test.shape
# Out:
# (40, 14)

# %%
train.shape
# Out:
# (160, 14)

# %%
# Seeing correlation between all variables
corr=df.corr()
corr
# Out:
#                        Customer_Satisfaction  Product_Quality  E_Commerce  \
# Customer_Satisfaction               1.000000         0.521052    0.341551
# Product_Quality                     0.521052         1.000000   -0.034316
# E_Commerce                          0.341551        -0.034316    1.000000
# Technical_Support                   0.202572         0.086604    0.040514
# Complaint_Resolution                0.597566         0.089551    0.191758
# Advertising                         0.353541        -0.053901    0.505198
# Product_Line                        0.646337         0.509295    0.077115
# Salesforce_Image                    0.477870        -0.116104    0.788225
# Competitive_Pricing                -0.282063        -0.448112    0.177294
# Warranty_Claims                     0.269225         0.109202    0.103102
# Packaging                           0.191509         0.135629   -0.041005
# Order_Billing                       0.540485         0.083037    0.216890
# Price_Flexibility                   0.031824        -0.487213    0.186243
# Delivery_Speed                      0.630172         0.066617    0.240808
#
#                        Technical_Support  Complaint_Resolution  Advertising  \
# Customer_Satisfaction           0.202572              0.597566     0.353541
# Product_Quality                 0.086604              0.089551    -0.053901
# E_Commerce                      0.040514              0.191758     0.505198
# Technical_Support               1.000000              0.151878     0.027820
# Complaint_Resolution            0.151878              1.000000     0.234220
# Advertising                     0.027820              0.234220     1.000000
# Product_Line                    0.169338              0.568294     0.116673
# Salesforce_Image                0.085700              0.255656     0.626754
# Competitive_Pricing            -0.091796             -0.077267     0.099175
# Warranty_Claims                 0.837819              0.180840     0.035151
# Packaging                      -0.037768              0.090359     0.062728
# Order_Billing                   0.120747              0.741084     0.230129
# Price_Flexibility              -0.029173              0.417718     0.260075
# Delivery_Speed                  0.132369              0.878067     0.323074
#
#                        Product_Line  Salesforce_Image  Competitive_Pricing  \
# Customer_Satisfaction      0.646337          0.477870            -0.282063
# Product_Quality            0.509295         -0.116104            -0.448112
# E_Commerce                 0.077115          0.788225             0.177294
# Technical_Support          0.169338          0.085700            -0.091796
# Complaint_Resolution       0.568294          0.255656            -0.077267
# Advertising                0.116673          0.626754             0.099175
# Product_Line               1.000000          0.050414            -0.482631
# Salesforce_Image           0.050414          1.000000             0.199981
# Competitive_Pricing       -0.482631          0.199981             1.000000
# Warranty_Claims            0.236551          0.162849            -0.085385
# Packaging                  0.126412          0.008659            -0.121316
# Order_Billing              0.443524          0.283672            -0.060485
# Price_Flexibility         -0.349225          0.272187             0.469746
# Delivery_Speed             0.611901          0.298677            -0.055161
#
#                        Warranty_Claims  Packaging  Order_Billing  \
# Customer_Satisfaction         0.269225   0.191509       0.540485
# Product_Quality               0.109202   0.135629       0.083037
# E_Commerce                    0.103102  -0.041005       0.216890
# Technical_Support             0.837819  -0.037768       0.120747
# Complaint_Resolution          0.180840   0.090359       0.741084
# Advertising                   0.035151   0.062728       0.230129
# Product_Line                  0.236551   0.126412       0.443524
# Salesforce_Image              0.162849   0.008659       0.283672
# Competitive_Pricing          -0.085385  -0.121316      -0.060485
# Warranty_Claims               1.000000   0.030308       0.204171
# Packaging                     0.030308   1.000000       0.137069
# Order_Billing                 0.204171   0.137069       1.000000
# Price_Flexibility            -0.040725   0.047022       0.419265
# Delivery_Speed                0.182976   0.147278       0.772972
#
#                        Price_Flexibility  Delivery_Speed
# Customer_Satisfaction           0.031824        0.630172
# Product_Quality                -0.487213        0.066617
# E_Commerce                      0.186243        0.240808
# Technical_Support              -0.029173        0.132369
# Complaint_Resolution            0.417718        0.878067
# Advertising                     0.260075        0.323074
# Product_Line                   -0.349225        0.611901
# Salesforce_Image                0.272187        0.298677
# Competitive_Pricing             0.469746       -0.055161
# Warranty_Claims                -0.040725        0.182976
# Packaging                       0.047022        0.147278
# Order_Billing                   0.419265        0.772972
# Price_Flexibility               1.000000        0.512981
# Delivery_Speed                  0.512981        1.000000

# %%
#y=f(x)

x_train=train.drop('Customer_Satisfaction',axis=1)
y_train=train['Customer_Satisfaction']
x_test=test.drop('Customer_Satisfaction',axis=1)
y_test=test['Customer_Satisfaction']

# %%
# creating first model with all variables: Ordinary Least Square(OLS) Technique used
model=ols('Customer_Satisfaction ~ Product_Quality + E_Commerce + Technical_Support + Complaint_Resolution + Advertising + Product_Line + Salesforce_Image + Competitive_Pricing + Warranty_Claims + Packaging + Order_Billing + Price_Flexibility + Delivery_Speed',
          data=train).fit()

# %%
'Customer_Satisfaction' + " ~ " + " + ".join(list(x_train.columns))
# Out:
# 'Customer_Satisfaction ~ Product_Quality + E_Commerce + Technical_Support + Complaint_Resolution + Advertising + Product_Line + Salesforce_Image + Competitive_Pricing + Warranty_Claims + Packaging + Order_Billing + Price_Flexibility + Delivery_Speed'

# %%
# Check Model summary
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     Customer_Satisfaction   R-squared:                       0.815
# Model:                               OLS   Adj. R-squared:                  0.798
# Method:                    Least Squares   F-statistic:                     49.40
# Date:                   Fri, 21 Aug 2020   Prob (F-statistic):           8.97e-47
# Time:                           19:37:56   Log-Likelihood:                -121.26
# No. Observations:                    160   AIC:                             270.5
# Df Residuals:                        146   BIC:                             313.6
# Df Model:                             13
# Covariance Type:               nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept               -2.5659      0.869     -2.954      0.004      -4.283      -0.849
# Product_Quality          0.4192      0.041     10.320      0.000       0.339       0.499
# E_Commerce              -0.1916      0.094     -2.042      0.043      -0.377      -0.006
# Technical_Support        0.0704      0.050      1.418      0.158      -0.028       0.168
# Complaint_Resolution     0.1526      0.077      1.983      0.049       0.000       0.305
# Advertising             -0.0137      0.051     -0.268      0.789      -0.115       0.087
# Product_Line             0.4313      0.198      2.174      0.031       0.039       0.823
# Salesforce_Image         0.5744      0.073      7.891      0.000       0.431       0.718
# Competitive_Pricing     -0.0487      0.033     -1.465      0.145      -0.114       0.017
# Warranty_Claims         -0.1027      0.095     -1.079      0.282      -0.291       0.085
# Packaging                0.0787      0.031      2.525      0.013       0.017       0.140
# Order_Billing            0.0580      0.080      0.727      0.469      -0.100       0.216
# Price_Flexibility        0.3601      0.209      1.719      0.088      -0.054       0.774
# Delivery_Speed          -0.2761      0.411     -0.672      0.503      -1.088       0.536
# ==============================================================================
# Omnibus:                        7.871   Durbin-Watson:                   2.138
# Prob(Omnibus):                  0.020   Jarque-Bera (JB):                7.878
# Skew:                          -0.541   Prob(JB):                       0.0195
# Kurtosis:                       3.111   Cond. No.                         433.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# checking the assumption of Linear regression
# Checking multicollinearity using vif
C_df = add_constant(df)
X=C_df

g=[]
for i in range(X.shape[1]):
    g.append(variance_inflation_factor(X.values, i))
g
# Out:
# [402.5547834449053,
#  5.106591130679372,
#  2.764919798548764,
#  2.8757863973348687,
#  3.5599502999304007,
#  4.812273996414206,
#  1.8296539462150558,
#  37.87314349154481,
#  5.34741096204325,
#  1.6707244838483755,
#  3.761154117150299,
#  1.1010295167469875,
#  2.7572033123950344,
#  33.08186591873373,
#  48.71201143871261]

# %%
#Removing variables with higher VIF values(i.e Productline and Delivery Speed) )

X=C_df.drop(['Delivery_Speed','Product_Line'],axis=1)

model=ols('Customer_Satisfaction ~ Product_Quality + E_Commerce + Technical_Support + Complaint_Resolution + Advertising + Salesforce_Image + Competitive_Pricing + Warranty_Claims + Packaging + Order_Billing + Price_Flexibility',
          data=train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     Customer_Satisfaction   R-squared:                       0.791
# Model:                               OLS   Adj. R-squared:                  0.776
# Method:                    Least Squares   F-statistic:                     50.95
# Date:                   Fri, 21 Aug 2020   Prob (F-statistic):           9.79e-45
# Time:                           19:40:06   Log-Likelihood:                -130.89
# No. Observations:                    160   AIC:                             285.8
# Df Residuals:                        148   BIC:                             322.7
# Df Model:                             11
# Covariance Type:               nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept               -1.2793      0.632     -2.025      0.045      -2.528      -0.031
# Product_Quality          0.4349      0.042     10.306      0.000       0.352       0.518
# E_Commerce              -0.1557      0.098     -1.581      0.116      -0.350       0.039
# Technical_Support        0.0622      0.052      1.189      0.236      -0.041       0.165
# Complaint_Resolution     0.3486      0.060      5.788      0.000       0.230       0.468
# Advertising              0.0326      0.053      0.620      0.536      -0.071       0.137
# Salesforce_Image         0.5351      0.076      7.050      0.000       0.385       0.685
# Competitive_Pricing     -0.0712      0.034     -2.068      0.040      -0.139      -0.003
# Warranty_Claims         -0.0709      0.100     -0.709      0.480      -0.269       0.127
# Packaging                0.0928      0.033      2.840      0.005       0.028       0.157
# Order_Billing            0.1430      0.079      1.814      0.072      -0.013       0.299
# Price_Flexibility        0.0107      0.060      0.178      0.859      -0.109       0.130
# ==============================================================================
# Omnibus:                        5.062   Durbin-Watson:                   2.297
# Prob(Omnibus):                  0.080   Jarque-Bera (JB):                5.171
# Skew:                          -0.421   Prob(JB):                       0.0754
# Kurtosis:                       2.743   Cond. No.                         257.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Dropping variables whose p-values are greater than 5%
model=ols('Customer_Satisfaction ~ Product_Quality + E_Commerce + Technical_Support + Complaint_Resolution + Advertising + Salesforce_Image + Competitive_Pricing + Warranty_Claims + Packaging + Order_Billing + Price_Flexibility',
          data=train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     Customer_Satisfaction   R-squared:                       0.791
# Model:                               OLS   Adj. R-squared:                  0.776
# Method:                    Least Squares   F-statistic:                     50.95
# Date:                   Fri, 21 Aug 2020   Prob (F-statistic):           9.79e-45
# Time:                           19:40:47   Log-Likelihood:                -130.89
# No. Observations:                    160   AIC:                             285.8
# Df Residuals:                        148   BIC:                             322.7
# Df Model:                             11
# Covariance Type:               nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept               -1.2793      0.632     -2.025      0.045      -2.528      -0.031
# Product_Quality          0.4349      0.042     10.306      0.000       0.352       0.518
# E_Commerce              -0.1557      0.098     -1.581      0.116      -0.350       0.039
# Technical_Support        0.0622      0.052      1.189      0.236      -0.041       0.165
# Complaint_Resolution     0.3486      0.060      5.788      0.000       0.230       0.468
# Advertising              0.0326      0.053      0.620      0.536      -0.071       0.137
# Salesforce_Image         0.5351      0.076      7.050      0.000       0.385       0.685
# Competitive_Pricing     -0.0712      0.034     -2.068      0.040      -0.139      -0.003
# Warranty_Claims         -0.0709      0.100     -0.709      0.480      -0.269       0.127
# Packaging                0.0928      0.033      2.840      0.005       0.028       0.157
# Order_Billing            0.1430      0.079      1.814      0.072      -0.013       0.299
# Price_Flexibility        0.0107      0.060      0.178      0.859      -0.109       0.130
# ==============================================================================
# Omnibus:                        5.062   Durbin-Watson:                   2.297
# Prob(Omnibus):                  0.080   Jarque-Bera (JB):                5.171
# Skew:                          -0.421   Prob(JB):                       0.0754
# Kurtosis:                       2.743   Cond. No.                         257.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model=ols('Customer_Satisfaction ~ Product_Quality + E_Commerce + Technical_Support + Complaint_Resolution + Advertising + Salesforce_Image + Competitive_Pricing + Packaging + Order_Billing',
          data=train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     Customer_Satisfaction   R-squared:                       0.790
# Model:                               OLS   Adj. R-squared:                  0.778
# Method:                    Least Squares   F-statistic:                     62.82
# Date:                   Fri, 21 Aug 2020   Prob (F-statistic):           2.02e-46
# Time:                           19:41:22   Log-Likelihood:                -131.18
# No. Observations:                    160   AIC:                             282.4
# Df Residuals:                        150   BIC:                             313.1
# Df Model:                              9
# Covariance Type:               nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept               -1.4611      0.534     -2.737      0.007      -2.516      -0.406
# Product_Quality          0.4306      0.037     11.779      0.000       0.358       0.503
# E_Commerce              -0.1566      0.098     -1.599      0.112      -0.350       0.037
# Technical_Support        0.0300      0.027      1.117      0.266      -0.023       0.083
# Complaint_Resolution     0.3550      0.057      6.230      0.000       0.242       0.468
# Advertising              0.0400      0.051      0.780      0.437      -0.061       0.141
# Salesforce_Image         0.5278      0.075      7.049      0.000       0.380       0.676
# Competitive_Pricing     -0.0699      0.032     -2.176      0.031      -0.133      -0.006
# Packaging                0.0899      0.032      2.817      0.005       0.027       0.153
# Order_Billing            0.1402      0.076      1.844      0.067      -0.010       0.291
# ==============================================================================
# Omnibus:                        4.688   Durbin-Watson:                   2.285
# Prob(Omnibus):                  0.096   Jarque-Bera (JB):                4.765
# Skew:                          -0.399   Prob(JB):                       0.0923
# Kurtosis:                       2.722   Cond. No.                         198.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model=ols('Customer_Satisfaction ~ Product_Quality + Product_Line + Complaint_Resolution +  Salesforce_Image  + Packaging ',
          data=train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     Customer_Satisfaction   R-squared:                       0.790
# Model:                               OLS   Adj. R-squared:                  0.784
# Method:                    Least Squares   F-statistic:                     116.1
# Date:                   Fri, 21 Aug 2020   Prob (F-statistic):           2.10e-50
# Time:                           19:41:38   Log-Likelihood:                -131.17
# No. Observations:                    160   AIC:                             274.3
# Df Residuals:                        154   BIC:                             292.8
# Df Model:                              5
# Covariance Type:               nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept               -2.0660      0.399     -5.172      0.000      -2.855      -1.277
# Product_Quality          0.3820      0.039      9.786      0.000       0.305       0.459
# Product_Line             0.1936      0.051      3.794      0.000       0.093       0.294
# Complaint_Resolution     0.3382      0.047      7.160      0.000       0.245       0.432
# Salesforce_Image         0.4775      0.042     11.347      0.000       0.394       0.561
# Packaging                0.1010      0.031      3.254      0.001       0.040       0.162
# ==============================================================================
# Omnibus:                        3.478   Durbin-Watson:                   2.238
# Prob(Omnibus):                  0.176   Jarque-Bera (JB):                3.475
# Skew:                          -0.355   Prob(JB):                        0.176
# Kurtosis:                       2.868   Cond. No.                         123.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# checking vif of remaining predictors
X=C_df.drop(['Delivery_Speed','Price_Flexibility', 'Warranty_Claims', 'Complaint_Resolution', 'Advertising', 'E_Commerce'],axis=1)

# %%
pd.Series([variance_inflation_factor(X.values, i) for i in range(X.shape[1])],
           index=X.columns)
# Out:
# const                    149.739315
# Customer_Satisfaction      4.110834
# Product_Quality            2.076585
# Technical_Support          1.054965
# Product_Line               2.369505
# Salesforce_Image           1.958846
# Competitive_Pricing        1.506672
# Packaging                  1.062752
# Order_Billing              1.653932
# dtype: float64

# %%
# Check Residual
y_pred=model.predict(x_train)
residual=y_train-y_pred
residual_percentage = (((y_train-y_pred)/y_train)*100)
residual_percentage
# Out:
# 137   -21.610758
# 163     3.535758
# 111    -5.881237
# 123     7.498319
# 109    -9.976894
# 141     9.385540
# 41      0.320228
# 130    -6.645586
# 140     3.123281
# 5     -14.097199
# 159     3.469891
# 100   -11.468652
# 11      0.161707
# 187    -1.757422
# 24    -20.134534
# 89      3.456639
# 66     -0.352719
# 8       3.258351
# 172    -3.150553
# 175     5.562263
# 28    -11.977108
# 133   -17.609251
# 94      3.992053
# 42      4.643647
# 169    -5.464692
# 82     10.052680
# 184    -8.066432
# 106     2.618129
# 108    -4.479866
# 143     1.875807
#          ...
# 183     6.628056
# 58      6.278673
# 33     11.827832
# 38      5.043002
# 103     0.535036
# 51    -24.281495
# 107     1.664977
# 170   -10.596759
# 4       5.735600
# 102   -20.651747
# 167    10.754138
# 37      0.785127
# 116    -0.355730
# 124    -7.422171
# 148     6.011970
# 31      6.745781
# 63      9.906325
# 47      6.559533
# 194   -14.530544
# 95      0.564153
# 177    -2.167243
# 162    -0.151323
# 7      12.016411
# 104     5.081058
# 75     -7.167243
# 43      1.169009
# 22     -2.968188
# 72      6.704459
# 15    -11.924244
# 168     7.856775
# Length: 160, dtype: float64

# %%
# Check normality of Residuals
t=pd.DataFrame(residual)
t.describe()
stats.probplot(residual, dist="norm",plot=plt)
plt.title("Normal Q-Q plot")
plt.show()

# %%
# 1. Checking normality of residuals
hist, bins = np.histogram(residual, bins=10)
hist
bins
width = 0.7 * (bins[1] - bins[0])
center = (bins[:-1] + bins[1:]) / 2
plt.bar(center,hist, align='center', width=width)
plt.ylabel('frequency')
plt.xlabel('residual')
plt.show()

# %%
# 3. Checking Homoscedasticity
plt.plot(y_train,residual,'o')
plt.xlabel('y_train')
plt.ylabel('residual')
# Out:
# Text(0, 0.5, 'residual')

# %%
# Breusch-Pagan Test
name = ['Lagrange multiplier statistic', 'p-value', 
        'f-value', 'f p-value']
bp = statsmodels.stats.diagnostic.het_breuschpagan(model.resid, model.model.exog)
bp
pd.DataFrame(name,bp)
# Out:
#                                       0
# 5.851426  Lagrange multiplier statistic
# 0.320945                        p-value
# 1.169157                        f-value
# 0.326878                      f p-value

# %%
#H0: variance of residuals is const(homo condition), H1: var.of residuals not const(hetero)
#We see that the p-value is 0.32. This is higher than 0.05, so we can no longer reject the null hypothesis of homoscedasticity.
#In this regard, the Breusch-Pagan test has confirmed that our results are not influenced by heteroscedasticity and we are therefore reliable

# %%
# Predicting the Test set results
y_pred=model.predict(x_test)

plt.plot(y_test,y_pred,'o')
plt.xlabel('Actual')
plt.ylabel('Predictions')
# Out:
# Text(0, 0.5, 'Predictions')

# %%
#Model evaluation metrics for regression-------------------------

from sklearn import metrics
print(metrics.mean_absolute_error(y_test, y_pred))#MAE
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))#RMSE
# Out:
# 0.6289553289168877
# 0.7465290637171569
